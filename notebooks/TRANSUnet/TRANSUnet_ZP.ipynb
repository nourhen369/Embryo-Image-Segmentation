# %%
import cv2
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.metrics import Recall, Precision, Accuracy, IoU
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
import tensorflow.keras.backend as K
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

# %%
SIZE=256
def read_image_tf(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (SIZE, SIZE))
    x = x / 255.0
    return x.astype(np.float32)

def read_mask_tf(path):
    path = path.decode()
    y = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    y = cv2.resize(y, (SIZE, SIZE))
    y[y != 0] = 255
    y = y / 255.0
    y = (y > 0.5).astype(np.float32)
    y = np.expand_dims(y, axis=-1)
    return y

def tf_parse(x_path, y_path):
    def _parse(x_path, y_path):
        x = read_image_tf(x_path)
        y = read_mask_tf(y_path)
        return x, y

    x, y = tf.numpy_function(_parse, [x_path, y_path], [tf.float32, tf.float32])
    x.set_shape([SIZE, SIZE, 3])
    y.set_shape([SIZE, SIZE, 1])
    return x, y

def tf_dataset(x_paths, y_paths, batch_size=16, shuffle=True):
    dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=1000)
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
def iou(y_true, y_pred):
    y_true = tf.round(y_true)
    y_pred = tf.round(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-15) / (union + 1e-15)
    return iou

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-7, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False),
    TensorBoard()
]

# %%
weight_decay=1e-8

def conv_block(x, filters, dropout=False):
    x = layers.Conv2D(filters, (3, 3), padding="same", kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(filters, (3, 3), padding="same", kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    if dropout:
        x = layers.Dropout(0.5)(x)

    return x

def encoder_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPooling2D((2, 2))(c)
    return c, p

def decoder_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

# %%
train_y = '/content/drive/MyDrive/PFA_Final/new_data/train/GT_ZP'
train_x = '/content/drive/MyDrive/PFA_Final/new_data/train/images'
test_y = '/content/drive/MyDrive/PFA_Final/new_data/test/GT_ZP'
test_x = '/content/drive/MyDrive/PFA_Final/new_data/test/images'
valid_y = '/content/drive/MyDrive/PFA_Final/new_data/valid/GT_ZP'
valid_x = '/content/drive/MyDrive/PFA_Final/new_data/valid/images'

train_images = sorted(glob(os.path.join(train_x, "*.bmp")))
train_masks  = sorted(glob(os.path.join(train_y, "*.bmp")))

test_images = sorted(glob(os.path.join(test_x, "*.bmp")))
test_masks  = sorted(glob(os.path.join(test_y, "*.bmp")))

valid_images = sorted(glob(os.path.join(valid_x, "*.bmp")))
valid_masks  = sorted(glob(os.path.join(valid_y, "*.bmp")))

# Create datasets
train_dataset = tf_dataset(train_images, train_masks, batch_size=16)
test_dataset  = tf_dataset(test_images, test_masks, batch_size=16,shuffle=False)
valid_dataset = tf_dataset(valid_images, valid_masks, batch_size=16, shuffle=False)
print("Number of training samples:", len(train_images))
print("Number of validation samples:", len(valid_images))
print("Number of testing samples:", len(test_images))

metrics = [dice_coef, iou, 'accuracy', Recall(), Precision()]
# Out:
# Number of training samples: 995
# Number of validation samples: 25
# Number of testing samples: 25

# %%
# image sequentialization: shaping the input x into a sequence of flattened 2D patches
def patch_embedding(x, patch_size, embed_dim):
    x = layers.Conv2D(embed_dim, kernel_size=patch_size, strides=patch_size, padding='valid')(x)
    # (B, H/P, W/P, D=embed_dim), reshaped to (B, N, D), N=H*W/P²
    x = layers.Reshape((-1, embed_dim))(x)
    return x

def transformer_block(x, embed_dim, num_heads, mlp_dim, dropout=0.1, return_attention=False):
    norm1 = layers.LayerNormalization(epsilon=1e-6)(x)
    mha = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)

    if return_attention:
        attn_output, attn_scores = mha(norm1, norm1, return_attention_scores=True)
    else:
        attn_output = mha(norm1, norm1)

    x = layers.Add()([x, attn_output])

    norm2 = layers.LayerNormalization(epsilon=1e-6)(x)
    mlp_output = layers.Dense(mlp_dim, activation='gelu')(norm2)
    mlp_output = layers.Dropout(dropout)(mlp_output)
    mlp_output = layers.Dense(embed_dim)(mlp_output)
    mlp_output = layers.Dropout(dropout)(mlp_output)
    x = layers.Add()([x, mlp_output])

    if return_attention:
        return x, attn_scores
    return x

def transformer_bottleneck(x, patch_size=1, num_layers=4, embed_dim=512, num_heads=8, mlp_dim=1024, return_all_attention=False):
    h, w, c = x.shape[1:]

    # Image Sequentialization.
    x = patch_embedding(x, patch_size, embed_dim)  # (B, N, D)

    # Positional encoding
    pos_emb = tf.Variable(tf.random.normal([1, x.shape[1], embed_dim]), trainable=True)

    # Patch Embedding.
    x = x + pos_emb

    attn_maps = []  # Store attention scores if needed
    for _ in range(num_layers):
        if return_all_attention:
            x, attn = transformer_block(x, embed_dim, num_heads, mlp_dim, return_attention=True)
            attn_maps.append(attn)
        else:
            x = transformer_block(x, embed_dim, num_heads, mlp_dim)

    # Reshape back to 2D
    new_h, new_w = h // patch_size, w // patch_size
    x = layers.Reshape((new_h, new_w, embed_dim))(x)

    if return_all_attention:
        return x, attn_maps
    return x

def build_transunet(input_shape, return_attention=False):
    inputs = tf.keras.Input(input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4 = conv_block(p3, 512, dropout=True)
    p4 = layers.MaxPooling2D((2, 2))(s4)

    # Transformer bottleneck
    if return_attention:
        b1, attention_maps = transformer_bottleneck(p4, patch_size=1, num_layers=4,
                                                    embed_dim=512, num_heads=8,
                                                    mlp_dim=1024, return_all_attention=True)
    else:
        b1 = transformer_bottleneck(p4, patch_size=1, num_layers=4,
                                    embed_dim=512, num_heads=8,
                                    mlp_dim=1024, return_all_attention=False)

    # Decoder
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    if return_attention:
        return Model(inputs, [outputs, attention_maps])
    return Model(inputs, outputs)

# %%
input_shape = ((SIZE, SIZE, 3))
model = build_transunet(input_shape, return_attention=False)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=dice_loss, metrics=metrics)
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=100,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 404s 5s/step - accuracy: 0.8005 - dice_coef: 0.3959 - iou: 0.3298 - loss: 0.6042 - precision: 0.3972 - recall: 0.5934 - val_accuracy: 0.6257 - val_dice_coef: 0.3928 - val_iou: 0.2982 - val_loss: 0.6008 - val_precision: 0.3047 - val_recall: 0.9957 - learning_rate: 1.0000e-04
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9327 - dice_coef: 0.7181 - iou: 0.6793 - loss: 0.2819 - precision: 0.7284 - recall: 0.9105 - val_accuracy: 0.8402 - val_dice_coef: 0.5253 - val_iou: 0.4538 - val_loss: 0.4662 - val_precision: 0.5084 - val_recall: 0.8396 - learning_rate: 1.0000e-04
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9456 - dice_coef: 0.7692 - iou: 0.7270 - loss: 0.2308 - precision: 0.7898 - recall: 0.9027 - val_accuracy: 0.9148 - val_dice_coef: 0.6704 - val_iou: 0.6130 - val_loss: 0.3226 - val_precision: 0.6974 - val_recall: 0.8514 - learning_rate: 1.0000e-04
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9520 - dice_coef: 0.7951 - iou: 0.7501 - loss: 0.2049 - precision: 0.8104 - recall: 0.9103 - val_accuracy: 0.9251 - val_dice_coef: 0.6936 - val_iou: 0.6170 - val_loss: 0.3003 - val_precision: 0.7795 - val_recall: 0.7590 - learning_rate: 1.0000e-04
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9557 - dice_coef: 0.8122 - iou: 0.7632 - loss: 0.1878 - precision: 0.8254 - recall: 0.9108 - val_accuracy: 0.9444 - val_dice_coef: 0.7668 - val_iou: 0.7032 - val_loss: 0.2294 - val_precision: 0.8376 - val_recall: 0.8213 - learning_rate: 1.0000e-04
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9593 - dice_coef: 0.8292 - iou: 0.7790 - loss: 0.1708 - precision: 0.8439 - recall: 0.9104 - val_accuracy: 0.9544 - val_dice_coef: 0.7917 - val_iou: 0.7454 - val_loss: 0.2071 - val_precision: 0.9010 - val_recall: 0.8117 - learning_rate: 1.0000e-04
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9614 - dice_coef: 0.8394 - iou: 0.7857 - loss: 0.1606 - precision: 0.8478 - recall: 0.9152 - val_accuracy: 0.9635 - val_dice_coef: 0.8509 - val_iou: 0.8151 - val_loss: 0.1509 - val_precision: 0.8548 - val_recall: 0.9375 - learning_rate: 1.0000e-04
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9637 - dice_coef: 0.8526 - iou: 0.7979 - loss: 0.1473 - precision: 0.8612 - recall: 0.9169 - val_accuracy: 0.9568 - val_dice_coef: 0.8547 - val_iou: 0.7924 - val_loss: 0.1469 - val_precision: 0.8055 - val_recall: 0.9723 - learning_rate: 1.0000e-04
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9653 - dice_coef: 0.8630 - iou: 0.8072 - loss: 0.1370 - precision: 0.8724 - recall: 0.9156 - val_accuracy: 0.9543 - val_dice_coef: 0.8529 - val_iou: 0.7851 - val_loss: 0.1495 - val_precision: 0.7932 - val_recall: 0.9763 - learning_rate: 1.0000e-04
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9674 - dice_coef: 0.8732 - iou: 0.8179 - loss: 0.1268 - precision: 0.8778 - recall: 0.9235 - val_accuracy: 0.9538 - val_dice_coef: 0.8538 - val_iou: 0.7798 - val_loss: 0.1472 - val_precision: 0.7913 - val_recall: 0.9767 - learning_rate: 1.0000e-04
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9670 - dice_coef: 0.8722 - iou: 0.8127 - loss: 0.1278 - precision: 0.8699 - recall: 0.9257 - val_accuracy: 0.9639 - val_dice_coef: 0.8773 - val_iou: 0.8177 - val_loss: 0.1242 - val_precision: 0.8441 - val_recall: 0.9572 - learning_rate: 1.0000e-04
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9693 - dice_coef: 0.8864 - iou: 0.8301 - loss: 0.1135 - precision: 0.8868 - recall: 0.9292 - val_accuracy: 0.9692 - val_dice_coef: 0.8913 - val_iou: 0.8402 - val_loss: 0.1108 - val_precision: 0.8784 - val_recall: 0.9434 - learning_rate: 1.0000e-04
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9693 - dice_coef: 0.8860 - iou: 0.8269 - loss: 0.1140 - precision: 0.8905 - recall: 0.9210 - val_accuracy: 0.9696 - val_dice_coef: 0.8965 - val_iou: 0.8417 - val_loss: 0.1054 - val_precision: 0.8775 - val_recall: 0.9475 - learning_rate: 1.0000e-04
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9706 - dice_coef: 0.8914 - iou: 0.8327 - loss: 0.1086 - precision: 0.8955 - recall: 0.9230 - val_accuracy: 0.9665 - val_dice_coef: 0.8916 - val_iou: 0.8301 - val_loss: 0.1102 - val_precision: 0.8526 - val_recall: 0.9629 - learning_rate: 1.0000e-04
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9714 - dice_coef: 0.8940 - iou: 0.8355 - loss: 0.1060 - precision: 0.8911 - recall: 0.9309 - val_accuracy: 0.9628 - val_dice_coef: 0.8820 - val_iou: 0.8121 - val_loss: 0.1193 - val_precision: 0.8408 - val_recall: 0.9548 - learning_rate: 1.0000e-04
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9715 - dice_coef: 0.8965 - iou: 0.8364 - loss: 0.1035 - precision: 0.8953 - recall: 0.9278 - val_accuracy: 0.9698 - val_dice_coef: 0.8996 - val_iou: 0.8408 - val_loss: 0.1013 - val_precision: 0.8756 - val_recall: 0.9515 - learning_rate: 1.0000e-04
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9738 - dice_coef: 0.9059 - iou: 0.8502 - loss: 0.0941 - precision: 0.9076 - recall: 0.9316 - val_accuracy: 0.9693 - val_dice_coef: 0.9014 - val_iou: 0.8413 - val_loss: 0.1004 - val_precision: 0.8707 - val_recall: 0.9554 - learning_rate: 1.0000e-04
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9720 - dice_coef: 0.8991 - iou: 0.8378 - loss: 0.1010 - precision: 0.9012 - recall: 0.9219 - val_accuracy: 0.9668 - val_dice_coef: 0.8976 - val_iou: 0.8326 - val_loss: 0.1060 - val_precision: 0.8647 - val_recall: 0.9464 - learning_rate: 1.0000e-04
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9725 - dice_coef: 0.8997 - iou: 0.8378 - loss: 0.1003 - precision: 0.9034 - recall: 0.9208 - val_accuracy: 0.9645 - val_dice_coef: 0.8923 - val_iou: 0.8208 - val_loss: 0.1092 - val_precision: 0.8419 - val_recall: 0.9654 - learning_rate: 1.0000e-04
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9749 - dice_coef: 0.9129 - iou: 0.8571 - loss: 0.0871 - precision: 0.9160 - recall: 0.9303 - val_accuracy: 0.9680 - val_dice_coef: 0.8907 - val_iou: 0.8193 - val_loss: 0.1102 - val_precision: 0.9301 - val_recall: 0.8708 - learning_rate: 1.0000e-04
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9714 - dice_coef: 0.9002 - iou: 0.8348 - loss: 0.0998 - precision: 0.9003 - recall: 0.9203 - val_accuracy: 0.9556 - val_dice_coef: 0.8732 - val_iou: 0.7864 - val_loss: 0.1293 - val_precision: 0.8055 - val_recall: 0.9624 - learning_rate: 1.0000e-04
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9739 - dice_coef: 0.9115 - iou: 0.8519 - loss: 0.0885 - precision: 0.9081 - recall: 0.9328 - val_accuracy: 0.9705 - val_dice_coef: 0.9075 - val_iou: 0.8437 - val_loss: 0.0931 - val_precision: 0.8746 - val_recall: 0.9580 - learning_rate: 1.0000e-04
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9772 - dice_coef: 0.9194 - iou: 0.8656 - loss: 0.0806 - precision: 0.9178 - recall: 0.9388 - val_accuracy: 0.9718 - val_dice_coef: 0.9124 - val_iou: 0.8503 - val_loss: 0.0887 - val_precision: 0.8841 - val_recall: 0.9538 - learning_rate: 1.0000e-04
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9778 - dice_coef: 0.9218 - iou: 0.8688 - loss: 0.0782 - precision: 0.9232 - recall: 0.9370 - val_accuracy: 0.9743 - val_dice_coef: 0.9191 - val_iou: 0.8619 - val_loss: 0.0830 - val_precision: 0.9088 - val_recall: 0.9377 - learning_rate: 1.0000e-04
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9771 - dice_coef: 0.9204 - iou: 0.8655 - loss: 0.0796 - precision: 0.9261 - recall: 0.9297 - val_accuracy: 0.9706 - val_dice_coef: 0.9121 - val_iou: 0.8482 - val_loss: 0.0904 - val_precision: 0.8760 - val_recall: 0.9566 - learning_rate: 1.0000e-04
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9770 - dice_coef: 0.9227 - iou: 0.8681 - loss: 0.0772 - precision: 0.9225 - recall: 0.9365 - val_accuracy: 0.9654 - val_dice_coef: 0.8988 - val_iou: 0.8249 - val_loss: 0.1025 - val_precision: 0.8422 - val_recall: 0.9715 - learning_rate: 1.0000e-04
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9777 - dice_coef: 0.9215 - iou: 0.8661 - loss: 0.0785 - precision: 0.9200 - recall: 0.9373 - val_accuracy: 0.9718 - val_dice_coef: 0.9117 - val_iou: 0.8474 - val_loss: 0.0906 - val_precision: 0.9121 - val_recall: 0.9167 - learning_rate: 1.0000e-04
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9786 - dice_coef: 0.9261 - iou: 0.8731 - loss: 0.0739 - precision: 0.9265 - recall: 0.9385 - val_accuracy: 0.9734 - val_dice_coef: 0.9187 - val_iou: 0.8586 - val_loss: 0.0841 - val_precision: 0.9072 - val_recall: 0.9339 - learning_rate: 1.0000e-04
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9786 - dice_coef: 0.9269 - iou: 0.8738 - loss: 0.0731 - precision: 0.9266 - recall: 0.9392 - val_accuracy: 0.9688 - val_dice_coef: 0.9071 - val_iou: 0.8376 - val_loss: 0.0943 - val_precision: 0.8679 - val_recall: 0.9557 - learning_rate: 1.0000e-04
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9786 - dice_coef: 0.9257 - iou: 0.8714 - loss: 0.0743 - precision: 0.9214 - recall: 0.9426 - val_accuracy: 0.9710 - val_dice_coef: 0.9137 - val_iou: 0.8489 - val_loss: 0.0888 - val_precision: 0.8848 - val_recall: 0.9471 - learning_rate: 1.0000e-04
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9790 - dice_coef: 0.9253 - iou: 0.8709 - loss: 0.0747 - precision: 0.9288 - recall: 0.9348 - val_accuracy: 0.9744 - val_dice_coef: 0.9219 - val_iou: 0.8630 - val_loss: 0.0811 - val_precision: 0.9186 - val_recall: 0.9265 - learning_rate: 1.0000e-04
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9800 - dice_coef: 0.9323 - iou: 0.8815 - loss: 0.0677 - precision: 0.9291 - recall: 0.9451 - val_accuracy: 0.9674 - val_dice_coef: 0.9052 - val_iou: 0.8327 - val_loss: 0.0973 - val_precision: 0.8649 - val_recall: 0.9503 - learning_rate: 1.0000e-04
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9808 - dice_coef: 0.9352 - iou: 0.8861 - loss: 0.0648 - precision: 0.9325 - recall: 0.9470 - val_accuracy: 0.9661 - val_dice_coef: 0.9005 - val_iou: 0.8248 - val_loss: 0.1004 - val_precision: 0.8544 - val_recall: 0.9567 - learning_rate: 1.0000e-04
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9802 - dice_coef: 0.9329 - iou: 0.8821 - loss: 0.0671 - precision: 0.9309 - recall: 0.9439 - val_accuracy: 0.9719 - val_dice_coef: 0.9157 - val_iou: 0.8506 - val_loss: 0.0875 - val_precision: 0.9084 - val_recall: 0.9221 - learning_rate: 1.0000e-04
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9800 - dice_coef: 0.9343 - iou: 0.8833 - loss: 0.0657 - precision: 0.9338 - recall: 0.9428 - val_accuracy: 0.9674 - val_dice_coef: 0.9051 - val_iou: 0.8318 - val_loss: 0.0970 - val_precision: 0.8664 - val_recall: 0.9482 - learning_rate: 1.0000e-04
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9800 - dice_coef: 0.9329 - iou: 0.8809 - loss: 0.0671 - precision: 0.9330 - recall: 0.9407 - val_accuracy: 0.9678 - val_dice_coef: 0.9064 - val_iou: 0.8334 - val_loss: 0.0941 - val_precision: 0.8541 - val_recall: 0.9701 - learning_rate: 1.0000e-04
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9816 - dice_coef: 0.9369 - iou: 0.8881 - loss: 0.0631 - precision: 0.9349 - recall: 0.9481 - val_accuracy: 0.9681 - val_dice_coef: 0.9074 - val_iou: 0.8350 - val_loss: 0.0934 - val_precision: 0.8556 - val_recall: 0.9697 - learning_rate: 1.0000e-04
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9826 - dice_coef: 0.9418 - iou: 0.8961 - loss: 0.0582 - precision: 0.9388 - recall: 0.9523 - val_accuracy: 0.9690 - val_dice_coef: 0.9094 - val_iou: 0.8382 - val_loss: 0.0926 - val_precision: 0.8739 - val_recall: 0.9481 - learning_rate: 1.0000e-04
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9819 - dice_coef: 0.9379 - iou: 0.8891 - loss: 0.0622 - precision: 0.9367 - recall: 0.9469 - val_accuracy: 0.9657 - val_dice_coef: 0.9009 - val_iou: 0.8236 - val_loss: 0.1005 - val_precision: 0.8541 - val_recall: 0.9543 - learning_rate: 1.0000e-04
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9835 - dice_coef: 0.9439 - iou: 0.8996 - loss: 0.0561 - precision: 0.9450 - recall: 0.9498 - val_accuracy: 0.9668 - val_dice_coef: 0.9025 - val_iou: 0.8264 - val_loss: 0.0993 - val_precision: 0.8712 - val_recall: 0.9364 - learning_rate: 1.0000e-04
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9804 - dice_coef: 0.9348 - iou: 0.8828 - loss: 0.0652 - precision: 0.9363 - recall: 0.9393
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9804 - dice_coef: 0.9348 - iou: 0.8829 - loss: 0.0652 - precision: 0.9363 - recall: 0.9394 - val_accuracy: 0.9636 - val_dice_coef: 0.8963 - val_iou: 0.8153 - val_loss: 0.1050 - val_precision: 0.8415 - val_recall: 0.9595 - learning_rate: 1.0000e-04
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9845 - dice_coef: 0.9491 - iou: 0.9082 - loss: 0.0508 - precision: 0.9458 - recall: 0.9587 - val_accuracy: 0.9734 - val_dice_coef: 0.9217 - val_iou: 0.8588 - val_loss: 0.0806 - val_precision: 0.8993 - val_recall: 0.9440 - learning_rate: 1.0000e-05
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9854 - dice_coef: 0.9502 - iou: 0.9105 - loss: 0.0498 - precision: 0.9518 - recall: 0.9551 - val_accuracy: 0.9731 - val_dice_coef: 0.9211 - val_iou: 0.8577 - val_loss: 0.0812 - val_precision: 0.8950 - val_recall: 0.9474 - learning_rate: 1.0000e-05
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9859 - dice_coef: 0.9510 - iou: 0.9123 - loss: 0.0490 - precision: 0.9530 - recall: 0.9564 - val_accuracy: 0.9724 - val_dice_coef: 0.9191 - val_iou: 0.8544 - val_loss: 0.0832 - val_precision: 0.8919 - val_recall: 0.9466 - learning_rate: 1.0000e-05
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9867 - dice_coef: 0.9545 - iou: 0.9185 - loss: 0.0455 - precision: 0.9548 - recall: 0.9610 - val_accuracy: 0.9729 - val_dice_coef: 0.9205 - val_iou: 0.8565 - val_loss: 0.0819 - val_precision: 0.8958 - val_recall: 0.9448 - learning_rate: 1.0000e-05
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9872 - dice_coef: 0.9556 - iou: 0.9207 - loss: 0.0444 - precision: 0.9570 - recall: 0.9607 - val_accuracy: 0.9724 - val_dice_coef: 0.9196 - val_iou: 0.8548 - val_loss: 0.0826 - val_precision: 0.8902 - val_recall: 0.9495 - learning_rate: 1.0000e-05
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9874 - dice_coef: 0.9573 - iou: 0.9233 - loss: 0.0427 - precision: 0.9596 - recall: 0.9613 - val_accuracy: 0.9714 - val_dice_coef: 0.9168 - val_iou: 0.8500 - val_loss: 0.0853 - val_precision: 0.8836 - val_recall: 0.9513 - learning_rate: 1.0000e-05
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9875 - dice_coef: 0.9571 - iou: 0.9232 - loss: 0.0429 - precision: 0.9564 - recall: 0.9643 - val_accuracy: 0.9723 - val_dice_coef: 0.9189 - val_iou: 0.8540 - val_loss: 0.0835 - val_precision: 0.8918 - val_recall: 0.9462 - learning_rate: 1.0000e-05
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9877 - dice_coef: 0.9581 - iou: 0.9250 - loss: 0.0419 - precision: 0.9627 - recall: 0.9602 - val_accuracy: 0.9718 - val_dice_coef: 0.9182 - val_iou: 0.8526 - val_loss: 0.0844 - val_precision: 0.8874 - val_recall: 0.9488 - learning_rate: 1.0000e-05
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9872 - dice_coef: 0.9565 - iou: 0.9220 - loss: 0.0435 - precision: 0.9557 - recall: 0.9633 - val_accuracy: 0.9719 - val_dice_coef: 0.9184 - val_iou: 0.8529 - val_loss: 0.0841 - val_precision: 0.8883 - val_recall: 0.9486 - learning_rate: 1.0000e-05
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9877 - dice_coef: 0.9585 - iou: 0.9256 - loss: 0.0414 - precision: 0.9591 - recall: 0.9638 - val_accuracy: 0.9722 - val_dice_coef: 0.9187 - val_iou: 0.8536 - val_loss: 0.0839 - val_precision: 0.8932 - val_recall: 0.9435 - learning_rate: 1.0000e-05
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9875 - dice_coef: 0.9577 - iou: 0.9240 - loss: 0.0423 - precision: 0.9611 - recall: 0.9603
# Epoch 52: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9875 - dice_coef: 0.9577 - iou: 0.9240 - loss: 0.0423 - precision: 0.9611 - recall: 0.9603 - val_accuracy: 0.9715 - val_dice_coef: 0.9174 - val_iou: 0.8512 - val_loss: 0.0851 - val_precision: 0.8858 - val_recall: 0.9493 - learning_rate: 1.0000e-05
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9882 - dice_coef: 0.9589 - iou: 0.9266 - loss: 0.0410 - precision: 0.9602 - recall: 0.9642 - val_accuracy: 0.9716 - val_dice_coef: 0.9174 - val_iou: 0.8511 - val_loss: 0.0850 - val_precision: 0.8856 - val_recall: 0.9496 - learning_rate: 1.0000e-06
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9880 - dice_coef: 0.9590 - iou: 0.9266 - loss: 0.0411 - precision: 0.9596 - recall: 0.9648 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8519 - val_loss: 0.0845 - val_precision: 0.8874 - val_recall: 0.9487 - learning_rate: 1.0000e-06
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9882 - dice_coef: 0.9604 - iou: 0.9290 - loss: 0.0396 - precision: 0.9612 - recall: 0.9656 - val_accuracy: 0.9717 - val_dice_coef: 0.9178 - val_iou: 0.8519 - val_loss: 0.0846 - val_precision: 0.8873 - val_recall: 0.9485 - learning_rate: 1.0000e-06
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9881 - dice_coef: 0.9581 - iou: 0.9253 - loss: 0.0419 - precision: 0.9618 - recall: 0.9613 - val_accuracy: 0.9717 - val_dice_coef: 0.9179 - val_iou: 0.8518 - val_loss: 0.0846 - val_precision: 0.8874 - val_recall: 0.9484 - learning_rate: 1.0000e-06
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9884 - dice_coef: 0.9610 - iou: 0.9301 - loss: 0.0390 - precision: 0.9630 - recall: 0.9653 - val_accuracy: 0.9717 - val_dice_coef: 0.9178 - val_iou: 0.8518 - val_loss: 0.0846 - val_precision: 0.8872 - val_recall: 0.9487 - learning_rate: 1.0000e-06
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9883 - dice_coef: 0.9591 - iou: 0.9269 - loss: 0.0409 - precision: 0.9603 - recall: 0.9641 - val_accuracy: 0.9716 - val_dice_coef: 0.9176 - val_iou: 0.8514 - val_loss: 0.0848 - val_precision: 0.8859 - val_recall: 0.9497 - learning_rate: 1.0000e-06
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9882 - dice_coef: 0.9586 - iou: 0.9261 - loss: 0.0414 - precision: 0.9598 - recall: 0.9644 - val_accuracy: 0.9719 - val_dice_coef: 0.9181 - val_iou: 0.8524 - val_loss: 0.0843 - val_precision: 0.8884 - val_recall: 0.9481 - learning_rate: 1.0000e-06
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9879 - dice_coef: 0.9585 - iou: 0.9258 - loss: 0.0415 - precision: 0.9598 - recall: 0.9637 - val_accuracy: 0.9719 - val_dice_coef: 0.9182 - val_iou: 0.8525 - val_loss: 0.0842 - val_precision: 0.8880 - val_recall: 0.9486 - learning_rate: 1.0000e-06
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9879 - dice_coef: 0.9586 - iou: 0.9259 - loss: 0.0414 - precision: 0.9600 - recall: 0.9633 - val_accuracy: 0.9719 - val_dice_coef: 0.9182 - val_iou: 0.8525 - val_loss: 0.0841 - val_precision: 0.8879 - val_recall: 0.9488 - learning_rate: 1.0000e-06
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9882 - dice_coef: 0.9606 - iou: 0.9293 - loss: 0.0394 - precision: 0.9628 - recall: 0.9645
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1e-07.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9882 - dice_coef: 0.9606 - iou: 0.9293 - loss: 0.0394 - precision: 0.9628 - recall: 0.9645 - val_accuracy: 0.9719 - val_dice_coef: 0.9181 - val_iou: 0.8523 - val_loss: 0.0843 - val_precision: 0.8876 - val_recall: 0.9491 - learning_rate: 1.0000e-06
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9880 - dice_coef: 0.9591 - iou: 0.9268 - loss: 0.0409 - precision: 0.9612 - recall: 0.9637 - val_accuracy: 0.9719 - val_dice_coef: 0.9181 - val_iou: 0.8522 - val_loss: 0.0843 - val_precision: 0.8876 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9887 - dice_coef: 0.9607 - iou: 0.9299 - loss: 0.0392 - precision: 0.9624 - recall: 0.9659 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8521 - val_loss: 0.0843 - val_precision: 0.8873 - val_recall: 0.9492 - learning_rate: 1.0000e-07
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9882 - dice_coef: 0.9589 - iou: 0.9266 - loss: 0.0411 - precision: 0.9595 - recall: 0.9652 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8521 - val_loss: 0.0843 - val_precision: 0.8874 - val_recall: 0.9491 - learning_rate: 1.0000e-07
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9883 - dice_coef: 0.9601 - iou: 0.9286 - loss: 0.0399 - precision: 0.9615 - recall: 0.9654 - val_accuracy: 0.9719 - val_dice_coef: 0.9180 - val_iou: 0.8522 - val_loss: 0.0843 - val_precision: 0.8876 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9880 - dice_coef: 0.9594 - iou: 0.9273 - loss: 0.0406 - precision: 0.9595 - recall: 0.9652 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0844 - val_precision: 0.8872 - val_recall: 0.9491 - learning_rate: 1.0000e-07
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9883 - dice_coef: 0.9596 - iou: 0.9278 - loss: 0.0404 - precision: 0.9594 - recall: 0.9661 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0843 - val_precision: 0.8874 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9880 - dice_coef: 0.9593 - iou: 0.9270 - loss: 0.0407 - precision: 0.9597 - recall: 0.9650 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8519 - val_loss: 0.0844 - val_precision: 0.8871 - val_recall: 0.9491 - learning_rate: 1.0000e-07
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9882 - dice_coef: 0.9595 - iou: 0.9277 - loss: 0.0404 - precision: 0.9607 - recall: 0.9650 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0844 - val_precision: 0.8870 - val_recall: 0.9493 - learning_rate: 1.0000e-07
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9880 - dice_coef: 0.9591 - iou: 0.9269 - loss: 0.0408 - precision: 0.9604 - recall: 0.9645 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8519 - val_loss: 0.0844 - val_precision: 0.8869 - val_recall: 0.9494 - learning_rate: 1.0000e-07
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9878 - dice_coef: 0.9591 - iou: 0.9267 - loss: 0.0409 - precision: 0.9599 - recall: 0.9647 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8521 - val_loss: 0.0843 - val_precision: 0.8872 - val_recall: 0.9492 - learning_rate: 1.0000e-07
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9883 - dice_coef: 0.9592 - iou: 0.9272 - loss: 0.0407 - precision: 0.9603 - recall: 0.9644 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8522 - val_loss: 0.0843 - val_precision: 0.8874 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9883 - dice_coef: 0.9603 - iou: 0.9289 - loss: 0.0397 - precision: 0.9618 - recall: 0.9648 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0843 - val_precision: 0.8873 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9886 - dice_coef: 0.9602 - iou: 0.9291 - loss: 0.0398 - precision: 0.9618 - recall: 0.9656 - val_accuracy: 0.9719 - val_dice_coef: 0.9182 - val_iou: 0.8523 - val_loss: 0.0842 - val_precision: 0.8878 - val_recall: 0.9488 - learning_rate: 1.0000e-07
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9882 - dice_coef: 0.9599 - iou: 0.9282 - loss: 0.0401 - precision: 0.9616 - recall: 0.9641 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8517 - val_loss: 0.0845 - val_precision: 0.8869 - val_recall: 0.9492 - learning_rate: 1.0000e-07
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9879 - dice_coef: 0.9575 - iou: 0.9241 - loss: 0.0425 - precision: 0.9595 - recall: 0.9627 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8521 - val_loss: 0.0843 - val_precision: 0.8875 - val_recall: 0.9489 - learning_rate: 1.0000e-07
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9882 - dice_coef: 0.9592 - iou: 0.9271 - loss: 0.0408 - precision: 0.9598 - recall: 0.9652 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8522 - val_loss: 0.0842 - val_precision: 0.8877 - val_recall: 0.9488 - learning_rate: 1.0000e-07
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9877 - dice_coef: 0.9583 - iou: 0.9253 - loss: 0.0417 - precision: 0.9593 - recall: 0.9636 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0843 - val_precision: 0.8874 - val_recall: 0.9489 - learning_rate: 1.0000e-07
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9881 - dice_coef: 0.9589 - iou: 0.9265 - loss: 0.0411 - precision: 0.9585 - recall: 0.9655 - val_accuracy: 0.9717 - val_dice_coef: 0.9179 - val_iou: 0.8518 - val_loss: 0.0845 - val_precision: 0.8870 - val_recall: 0.9491 - learning_rate: 1.0000e-07
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9884 - dice_coef: 0.9603 - iou: 0.9290 - loss: 0.0397 - precision: 0.9623 - recall: 0.9651 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8518 - val_loss: 0.0845 - val_precision: 0.8870 - val_recall: 0.9491 - learning_rate: 1.0000e-07
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9882 - dice_coef: 0.9596 - iou: 0.9277 - loss: 0.0404 - precision: 0.9614 - recall: 0.9638 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8522 - val_loss: 0.0843 - val_precision: 0.8875 - val_recall: 0.9489 - learning_rate: 1.0000e-07
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9881 - dice_coef: 0.9583 - iou: 0.9255 - loss: 0.0417 - precision: 0.9598 - recall: 0.9635 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8522 - val_loss: 0.0843 - val_precision: 0.8876 - val_recall: 0.9489 - learning_rate: 1.0000e-07
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9882 - dice_coef: 0.9588 - iou: 0.9264 - loss: 0.0412 - precision: 0.9599 - recall: 0.9642 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0843 - val_precision: 0.8873 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9881 - dice_coef: 0.9598 - iou: 0.9279 - loss: 0.0402 - precision: 0.9606 - recall: 0.9652 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8518 - val_loss: 0.0845 - val_precision: 0.8868 - val_recall: 0.9494 - learning_rate: 1.0000e-07
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9887 - dice_coef: 0.9615 - iou: 0.9313 - loss: 0.0385 - precision: 0.9629 - recall: 0.9663 - val_accuracy: 0.9718 - val_dice_coef: 0.9179 - val_iou: 0.8519 - val_loss: 0.0844 - val_precision: 0.8870 - val_recall: 0.9492 - learning_rate: 1.0000e-07
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9877 - dice_coef: 0.9568 - iou: 0.9229 - loss: 0.0432 - precision: 0.9565 - recall: 0.9644 - val_accuracy: 0.9718 - val_dice_coef: 0.9180 - val_iou: 0.8520 - val_loss: 0.0844 - val_precision: 0.8873 - val_recall: 0.9490 - learning_rate: 1.0000e-07
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9884 - dice_coef: 0.9606 - iou: 0.9294 - loss: 0.0394 - precision: 0.9627 - recall: 0.9648 - val_accuracy: 0.9717 - val_dice_coef: 0.9178 - val_iou: 0.8517 - val_loss: 0.0846 - val_precision: 0.8868 - val_recall: 0.9492 - learning_rate: 1.0000e-07
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9882 - dice_coef: 0.9599 - iou: 0.9282 - loss: 0.0401 - precision: 0.9611 - recall: 0.9648 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8522 - val_loss: 0.0843 - val_precision: 0.8877 - val_recall: 0.9487 - learning_rate: 1.0000e-07
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9882 - dice_coef: 0.9594 - iou: 0.9273 - loss: 0.0406 - precision: 0.9604 - recall: 0.9647 - val_accuracy: 0.9718 - val_dice_coef: 0.9181 - val_iou: 0.8521 - val_loss: 0.0843 - val_precision: 0.8876 - val_recall: 0.9487 - learning_rate: 1.0000e-07
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9881 - dice_coef: 0.9592 - iou: 0.9269 - loss: 0.0408 - precision: 0.9608 - recall: 0.9640 - val_accuracy: 0.9717 - val_dice_coef: 0.9178 - val_iou: 0.8516 - val_loss: 0.0846 - val_precision: 0.8866 - val_recall: 0.9493 - learning_rate: 1.0000e-07
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9879 - dice_coef: 0.9589 - iou: 0.9262 - loss: 0.0411 - precision: 0.9605 - recall: 0.9635 - val_accuracy: 0.9717 - val_dice_coef: 0.9179 - val_iou: 0.8518 - val_loss: 0.0845 - val_precision: 0.8869 - val_recall: 0.9492 - learning_rate: 1.0000e-07

# %%
model.evaluate(test_dataset)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.9692 - dice_coef: 0.9087 - iou: 0.8360 - loss: 0.0921 - precision: 0.8790 - recall: 0.9424
# [0.09109863638877869,
#  0.9100173711776733,
#  0.8384640216827393,
#  0.9701281785964966,
#  0.9432830810546875,
#  0.8800254464149475]

# %%
# Make predictions on a batch of test images
test_batch = next(iter(test_dataset))
test_images_batch, test_masks_batch = test_batch

predictions = model.predict(test_images_batch)

num_samples = 5
plt.figure(figsize=(15, 10))

for i in range(num_samples):
    # Original Image
    plt.subplot(num_samples, 3, i * 3 + 1)
    plt.imshow(test_images_batch[i])
    plt.title("Original Image")
    plt.axis('off')

    # True Mask
    plt.subplot(num_samples, 3, i * 3 + 2)
    plt.imshow(np.squeeze(test_masks_batch[i]), cmap='gray')
    plt.title("True Mask")
    plt.axis('off')

    # Predicted Mask
    plt.subplot(num_samples, 3, i * 3 + 3)
    plt.imshow(np.squeeze(predictions[i]), cmap='gray')
    plt.title("Predicted Mask")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
